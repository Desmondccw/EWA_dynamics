# %%
from EWA_mod import * 
import numpy as np

# %% [markdown]
# Demonstration of finding the fixed points using custom Runga-Kutta 45 function with adaptive sizes.

# %%
no_action= 200
true_r = 0.5

r_scaled= np.sqrt(no_action) * true_r
run_till_convergence(n_players= 2, n_actions= no_action, gamma= 0, r= r_scaled, time_interval=200)

# %% [markdown]
# Sample strategy evolution the same choices of r and no. of actions.

# %%
output= mod_simulate_random_game(n_players= 2, n_actions= no_action, gamma= 0, r= r_scaled, time_interval=2000, visualise= True)
