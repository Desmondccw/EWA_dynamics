# %%
from EWA_mod import * 
import numpy as np
'''Total runtime: ~ 12mins'''
# Out:
# 'Total runtime: ~ 12mins'

# %% [markdown]
# Sample runs

# %%
no_action= 50
true_r = 10

r_scaled= np.sqrt(no_action) * true_r

output= simulate_random_game(n_actions= no_action, gamma= -0.8, r= r_scaled, time_interval=4000, visualise= True, est_KY_dim= True)
# Out:
# Estimated KY dimensition: 5.76061288902863

# %%
no_action= 50
true_r = 4

r_scaled= np.sqrt(no_action) * true_r

output= simulate_random_game(n_actions= no_action, gamma= -0.8, r= r_scaled, time_interval=4000, visualise= True, est_KY_dim= True)
# Out:
# Estimated KY dimensition: 0

# %%
no_action= 100
true_r = 1

r_scaled= np.sqrt(no_action) * true_r

output= simulate_random_game(n_actions= no_action, gamma= 0, r= r_scaled, time_interval=5000, visualise= True, est_KY_dim= False)
