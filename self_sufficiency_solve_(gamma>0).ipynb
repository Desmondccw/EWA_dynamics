# %% [markdown]
# In this notebook, we will estimate the fixed points corresponding to EWA learning dynamics in the Gamma > 0 (potential-like game) setting.  Recall the fixed points of the effective dynamics $x(z)$ obey the following equation as found via the path integral method.
#
# \begin{equation}
# 0=  \left[\Gamma  x(z) \chi - \frac{1}{r} \ln x(z) + \sqrt{q}z - \rho \right]x(z)
# \end{equation}
#
# where:
#
# $z \sim \mathcal{N} (0,1)$
#
# For $\Gamma > 0$,
# $ \left[\Gamma  x(z) \chi - \frac{1}{r} \ln x(z) + \sqrt{q}z - \rho \right] = 0 $ does not have a solution for all $z$.  Thus, we have to set $x(z) = 0 $ for some $z$.
#
# ## The most Interior fixed point
#
# We propose the following Ansatz for $x(z)$ in this regime.
#
# $\begin{align}
# x(z)=
# \begin{cases}
# Ke^{bz+ax(z)} \; \; &, z < z_{crit} \\
# 0 \; \; &, z \geq z_{crit}
# \end{cases}
# \end{align}$
#
# where:
# $\begin{align}
# a&= \Gamma \chi r \\
# b&= \sqrt{q} r > 0 \\
# z_{crit} &= -\frac{1}{b} \left( 1 + \ln(\alpha K)\right) \\
# \end{align}$
#
# The parameters, $(K, a , b)$ ,must obey the following 'self-sufficiency' conditions:
#
# $\begin{align}
# q &= \int^{z_{crit}}_{-\infty} x^2(z) Dz \notag \\
# 1 &= \int^{z_{crit}}_{-\infty} x(z) Dz\notag  \\
# \chi &= \int^{z_{crit}}_{-\infty} \frac{d x(z)}{dz} Dz\notag  \\
# \end{align}$
#
# where:
#
# $Dz$ is pdf corresponding to the standard normal.
#
# This Ansatz represents the 'most-interior' fixed points of our dynamics.  Further fixed points of $x(z)$  could be found by reducing $z_{crit}$, thereby increasing the regime where $x(z) = 0$

# %%
#Import Packages

import numpy as np
from scipy.integrate import quad
import scipy.stats as stats
from scipy import optimize
from scipy.optimize import minimize
from scipy.special import lambertw

import warnings

from EWA_mod import * 
import itertools

#To enable running parallelised for loops
from joblib import Parallel, delayed

# %% [markdown]
# ### Define functions x(z), dx/dz and Dz

# %%
def return_x(K, a , b):

    '''Input: 
    Parameters K, a , b'''
    '''Output: 
    functions- x(z), dx(z)/dz
    crit_values- z_crit, x(z_crit)'''

    def x(z):
        return np.real(-(1/a) * lambertw( -K * a * np.exp(b*z) , tol=1e-12))
    
    def deriv_x(z):
        xz= x(z)

        return b*xz/  (1- a* xz)
    
    x_crit = 1/a
    
    crit_z = -(1+ np.log(a* K)) / b
    
    return x, deriv_x, crit_z , x_crit

def Dz(z):
    '''Pdf of standard normal'''
    return np.exp(-z**2/2) / np.sqrt(2*np.pi)

# %% [markdown]
# ### Define loss functions and stability condition

# %% [markdown]
# The stability condition takes this form:
#
# $$
# \begin{align}
#  \int \bigg|\frac{ 1}{r x^\star} - \Gamma  \chi\bigg|^{-2} Dz < \phi ^{-1}
# \end{align}
# $$
#
# where:
#
# $\phi$ is the propotion of non-extinct strategies.  We have included a function to check the stability condition below

# %%
def custom_loss(r, gamma):

    def loss(x0):

        '''Deviation from self-sufficiency condition is treated as a loss function to minimise'''
        '''Do gradient descent -> 0 to find optimal parameters'''

        K,a,b =x0

        x, deriv_x, crit_z , x_crit= return_x(K,a ,b)

        integrand_1  = lambda z : x(z) * Dz(z)
        integrand_2  = lambda z : x(z)**2 * Dz(z)
        integrand_3  = lambda z : deriv_x(z)* Dz(z)

        '''Scipy quad integration with a bazillion cuts for numerical accuracy'''
        cuts= 5000000
        eps= 1e-9

        loss_1 = 1 - quad(integrand_1, -np.inf, crit_z- eps, epsabs=1.49e-12, epsrel=1.49e-12, limit=cuts)[0]
        loss_2 = (b/r)**2 - quad(integrand_2, -np.inf, crit_z- eps, epsabs=1.49e-12, epsrel=1.49e-12, limit=cuts)[0]
        loss_3 = (a/(gamma*r)) - ( quad(integrand_3, -np.inf, crit_z- eps, epsabs=1.49e-12, epsrel=1.49e-12, limit=cuts)[0] - x_crit * Dz(crit_z))

        '''Loss = square deviation from self-sufficency equations'''
        losses= loss_1**2 +  loss_2**2 + loss_3**2

        return losses
    
    def stability_check(x0):

        '''Checks the stability given a choice of x(z)'''

        '''Output = +ve   =>  Unstable'''
        '''Output = -ve   =>  Stable'''
        '''Output = 0   =>  Boundary of Stability'''

        K,a,b = x0

        x, deriv_x, crit_z , x_crit= return_x(K,a ,b)

        stability_integrand = lambda z: Dz(z) * ( x(z)/ (1-a*x(z)) )**2

        cuts= 5000000
        eps= 2e-8

        stability_integral= quad(stability_integrand, -np.inf, crit_z- eps, epsabs=1.49e-15, epsrel=1.49e-15, limit=cuts )[0] + stability_integrand(crit_z -0.5*eps) * eps
        phi =   stats.norm.cdf(crit_z)
      
        #phi*r**2 *stability_integral - 1
        return phi*r**2 *stability_integral - 1 
    
    return loss, stability_check

def stability_r(gamma,x0 ,r0):

  '''Find Stability Boundary given Gamma, r  and initial guess x0 (K0, a0, b0) (only works if initial guess is close enough)'''
    
  def root_function(r):

    loss_f, stab_check= custom_loss(r, gamma)
    res= minimize(loss_f, x0, bounds = [(1e-7, None), (1e-8, None), (1e-8, None)], method='Nelder-Mead', tol=1e-8)

    return stab_check(res.x)
  
  sol= optimize.root(root_function, r0, tol=1e-8, method='lm', options = {'maxstep': 0.01})

  return sol

# %% [markdown]
# ### Demo on a selected r and $\Gamma$

# %%
#Initialise initial guess

K0, a0, b0 = 0.7592959,  0.03574393, 0.65948725
r , gamma = 0.41, 0.1
initial_guess= [K0, a0 ,b0]

#Create loss functions corresponding to r and Gamma
loss_f, stab_check= custom_loss(r= r, gamma= gamma)

#Disable Integration warning.  Often our integration has a 'pole' but the integration converges. The magnitude of the estimated loss gives us a rough idea, though it is likely an underestimate.
warnings.filterwarnings('ignore', category=UserWarning)

#Conduct gradient-descent to identify optimum parameter values
#Enforce positive definite bounds
res= minimize(loss_f, initial_guess, bounds = [(1e-7, None), (1e-8, None), (1e-8, None)], method='Nelder-Mead', tol=1e-8)

#Display loss (deviation from self-sufficiency eq)
print(f'loss: {res.fun}')
#Display parameters K,a,b.
print(f'parameters: {res.x}')
#Check stability 
print(f'stab_check: {stab_check(res.x)}')

#Reenable warnings
warnings.filterwarnings('default', category=UserWarning)
# Out:
# loss: 3.678512968543817e-16
# parameters: [0.87909296 0.01924618 0.45806954]
# stab_check: -0.7767516013367338

# %% [markdown]
# ### Comparing theory vs empirical results

# %% [markdown]
# Code below is to run ensemble games in Parallel and record fixed points upon convergence.

# %%
def hunt_fixed_points(true_r, actions, i , gamma):

    '''Finds fixed points given choice of r and gamma'''
    r_scaled= np.sqrt(actions) * true_r

    if i*actions%2048==0:
        print(f'Running iter {i}')

    return np.array(run_till_convergence(n_actions= actions, gamma= gamma, r= r_scaled, time_interval=200))


def multiple_runs(true_r, actions, gamma, n_runs= 8):
    '''Parrallelises n_runs'''
    fixed_points= Parallel( n_jobs = 48)(delayed(hunt_fixed_points)(true_r, actions, i, gamma) for i in range(n_runs))
    
    fp= np.array(list(itertools.chain(*fixed_points)))

    fp= [p for p in fp if p < 1]

    print(f'Converged: {len(fp)/actions //2} / {n_runs}')

    return fp

# %%
fp= multiple_runs(true_r= 0.41, actions= 320, gamma= 0.1, n_runs= 160)

np.savetxt("fixed_points_gamma01_r041.csv", fp, delimiter=",")
# Out:
# Running iter 0
# Derivative norm at endpoint: 1.3362524989112048e-15
# Derivative norm at endpoint: 2.1257819034619844e-15
# Derivative norm at endpoint: 3.4434621145277636e-16
# Derivative norm at endpoint: 1.1628915665275694e-15
# Derivative norm at endpoint: 2.282000633259122e-15
# Derivative norm at endpoint: 4.201248898641313e-15
# Derivative norm at endpoint: 1.2105240727008156e-15
# Derivative norm at endpoint: 6.980007278349271e-15
# Derivative norm at endpoint: 3.4652393041579005e-15
# Derivative norm at endpoint: 1.83971438904706e-15
# Derivative norm at endpoint: 2.969939497850709e-15
# Derivative norm at endpoint: 1.4982537176600279e-15
# Derivative norm at endpoint: 1.1887210567192523e-15
# Derivative norm at endpoint: 1.725112365023308e-15
# Derivative norm at endpoint: 2.7582542869300443e-15
# Derivative norm at endpoint: 1.3449234281075564e-15
# Running iter 32
# Derivative norm at endpoint: 7.598561355455572e-15
# Running iter 64
# Derivative norm at endpoint: 4.5333371593894786e-15
# Derivative norm at endpoint: 2.2078549395485136e-16
# Derivative norm at endpoint: 8.855018073838276e-16
# Derivative norm at endpoint: 1.530002434802945e-15
# Derivative norm at endpoint: 1.0355021117084053e-15
# Derivative norm at endpoint: 1.2557238782403575e-15
# Derivative norm at endpoint: 1.4330297260754602e-15
# Derivative norm at endpoint: 4.490296041581072e-16
# Derivative norm at endpoint: 8.433543521137219e-16
# Derivative norm at endpoint: 3.887877814170638e-15
# Derivative norm at endpoint: 1.3476054561435535e-15
# Derivative norm at endpoint: 1.4015382892853218e-15
# Derivative norm at endpoint: 2.8483088459104344e-15
# Derivative norm at endpoint: 3.721877352281907e-16
# Derivative norm at endpoint: 3.963298446315697e-15
# Derivative norm at endpoint: 7.846549173909743e-16
# Derivative norm at endpoint: 2.378629231231168e-15
# Derivative norm at endpoint: 2.2151949074621228e-15
# Derivative norm at endpoint: 3.9035964410872645e-15
# Derivative norm at endpoint: 3.1677324850453156e-15
# Derivative norm at endpoint: 5.054452464089688e-15
# Derivative norm at endpoint: 1.3780035081079696e-15
# Derivative norm at endpoint: 5.0195862594724294e-15
# Derivative norm at endpoint: 8.98690138414566e-16
# Derivative norm at endpoint: 1.6102491314107437e-15
# Derivative norm at endpoint: 4.408069694326396e-15
# Derivative norm at endpoint: 4.96108487980986e-16
# Derivative norm at endpoint: 6.0094252512718035e-16
# Derivative norm at endpoint: 2.7755825468047958e-15
# Derivative norm at endpoint: 5.009189688635719e-15
# Derivative norm at endpoint: 6.099290405014038e-16
# Derivative norm at endpoint: 3.394673775040326e-15
# Derivative norm at endpoint: 5.05291443551742e-15
# Derivative norm at endpoint: 2.230023695269729e-15
# Running iter 96
# Derivative norm at endpoint: 1.6812510819526868e-15
# Derivative norm at endpoint: 1.9847851621911287e-15
# Derivative norm at endpoint: 2.649518430673238e-15
# Derivative norm at endpoint: 2.9432291454690654e-15
# Derivative norm at endpoint: 3.76313648539823e-15
# Derivative norm at endpoint: 1.8068821911454622e-15
# Derivative norm at endpoint: 2.3294171355521967e-15
# Derivative norm at endpoint: 2.7938696895329307e-15
# Derivative norm at endpoint: 6.661681314310208e-15
# Derivative norm at endpoint: 8.711039948053467e-16
# Derivative norm at endpoint: 2.340257107486122e-16
# Derivative norm at endpoint: 2.386033221431774e-16
# Derivative norm at endpoint: 2.389499742774358e-16
# Derivative norm at endpoint: 2.377882526641327e-16
# Derivative norm at endpoint: 2.3054631246968525e-16
# Derivative norm at endpoint: 2.4785703494240885e-16
# Derivative norm at endpoint: 4.422313344240959e-15
# Derivative norm at endpoint: 2.710229830899528e-15
# Derivative norm at endpoint: 1.1019957498673688e-15
# Derivative norm at endpoint: 5.609483261841628e-15
# Derivative norm at endpoint: 3.3274842955416024e-16
# Derivative norm at endpoint: 7.174988163628541e-15
# Derivative norm at endpoint: 3.4873278069789102e-15
# Derivative norm at endpoint: 6.745983372219111e-16
# Derivative norm at endpoint: 1.0025465943402014e-15
# Derivative norm at endpoint: 1.3888659367880907e-15
# Derivative norm at endpoint: 1.6881734143818077e-15
# Derivative norm at endpoint: 2.569287144323292e-15
# Derivative norm at endpoint: 3.604184957862875e-15
# Derivative norm at endpoint: 1.5235825626640077e-15
# Running iter 128
# Derivative norm at endpoint: 2.9484895084313552e-15
# Derivative norm at endpoint: 2.852361925106556e-15
# Derivative norm at endpoint: 2.2654007965413975e-15
# Derivative norm at endpoint: 2.217402212070093e-15
# Derivative norm at endpoint: 2.0761310405668607e-15
# Derivative norm at endpoint: 5.937088720630573e-16
# Derivative norm at endpoint: 1.4211485474397197e-15
# Derivative norm at endpoint: 1.6070133146195723e-15
# Derivative norm at endpoint: 3.3296086333333443e-15
# Derivative norm at endpoint: 1.5475629617774745e-15
# Derivative norm at endpoint: 4.3230282734571315e-15
# Derivative norm at endpoint: 2.226092323005808e-15
# Derivative norm at endpoint: 6.0044808254615995e-15
# Derivative norm at endpoint: 1.5796811775022242e-15
# Derivative norm at endpoint: 6.51479040330371e-15
# Derivative norm at endpoint: 6.605626015321244e-16
# Derivative norm at endpoint: 1.3391338390327398e-15
# Derivative norm at endpoint: 9.641510732528917e-16
# Derivative norm at endpoint: 7.986484356382055e-15
# Derivative norm at endpoint: 3.029069605423324e-15
# Derivative norm at endpoint: 2.2321193142909625e-15
# Derivative norm at endpoint: 8.826812770381918e-16
# Derivative norm at endpoint: 9.444341197017484e-15
# Derivative norm at endpoint: 1.4979138869725788e-15
# Derivative norm at endpoint: 4.856594047090239e-16
# Derivative norm at endpoint: 2.3531837860628747e-15
# Derivative norm at endpoint: 9.064467708001262e-16
# Derivative norm at endpoint: 9.136467429515232e-16
# Derivative norm at endpoint: 2.2102425931089668e-16
# Derivative norm at endpoint: 4.780743060215132e-15
# Derivative norm at endpoint: 9.832692024517092e-15
# Derivative norm at endpoint: 7.774131720645708e-15
# Derivative norm at endpoint: 4.310571792289404e-15
# Derivative norm at endpoint: 2.2789578921996096e-16
# Derivative norm at endpoint: 4.0229479426122285e-15
# Derivative norm at endpoint: 7.56537288977293e-16
# Derivative norm at endpoint: 2.257866351357663e-15
# Derivative norm at endpoint: 4.638101506532957e-15
# Derivative norm at endpoint: 7.65432327264434e-15
# Derivative norm at endpoint: 1.1709696973774635e-15
# Derivative norm at endpoint: 7.911266794331993e-16
# Derivative norm at endpoint: 1.0652591958394628e-15
# Derivative norm at endpoint: 5.182961023281405e-15
# Derivative norm at endpoint: 1.8261627841888226e-15
# Derivative norm at endpoint: 6.827946943275444e-15
# Derivative norm at endpoint: 1.6534903513393445e-15
# Derivative norm at endpoint: 4.485443002498968e-15
# Derivative norm at endpoint: 7.103176626492732e-15
# Derivative norm at endpoint: 9.595798379320908e-15
# Derivative norm at endpoint: 1.2139335846422876e-15
# Derivative norm at endpoint: 2.1659526268003766e-15
# Derivative norm at endpoint: 1.233474626127783e-15
# Derivative norm at endpoint: 1.3909008248078824e-15
# Derivative norm at endpoint: 1.6977838338781247e-15
# Derivative norm at endpoint: 1.6383464122759556e-15
# Derivative norm at endpoint: 1.98016038074643e-15
# Derivative norm at endpoint: 8.47353697471505e-15
# Derivative norm at endpoint: 2.208104808908762e-15
# Derivative norm at endpoint: 2.4780229656992923e-15
# Derivative norm at endpoint: 1.6268397933787943e-15
# Derivative norm at endpoint: 6.820477216952336e-15
# Derivative norm at endpoint: 2.6980783897930157e-15
# Derivative norm at endpoint: 1.1660671584618024e-15
# Derivative norm at endpoint: 1.854932185541576e-15
# Derivative norm at endpoint: 7.316850720516432e-16
# Derivative norm at endpoint: 4.778394734210079e-15
# Derivative norm at endpoint: 9.812174499750943e-16
# Derivative norm at endpoint: 7.290058767248105e-16
# Derivative norm at endpoint: 5.007326127567975e-15
# Derivative norm at endpoint: 4.490039318227983e-15
# Derivative norm at endpoint: 1.274061943802511e-15
# Derivative norm at endpoint: 1.546142674465028e-15
# Derivative norm at endpoint: 3.5527643432517625e-15
# Derivative norm at endpoint: 1.8879399593997956e-15
# Derivative norm at endpoint: 5.863738131688532e-16
# Derivative norm at endpoint: 2.3483295970214843e-16
# Derivative norm at endpoint: 2.4007360811943746e-16
# Derivative norm at endpoint: 2.326685736841711e-16
# Derivative norm at endpoint: 2.349066565065847e-16
# Converged: 160.0 / 160

# %% [markdown]
# Function to plot given parameters K, a ,b (found earlier and now res.x) and n_actions.

# %%
def plot_x_pdf(parameters, n_actions):

    K, a, b= parameters

    x, deriv_x, crit_z , x_crit = return_x(K, a , b)

    def output_x(z):

        if z > crit_z - 1e-8:
            return 0
        else:
            return x(z)
        
    zz=  np.random.normal(size= 1000000)

    xz_array= [output_x(z) for z in zz]
    
    print(f'crit_z= {crit_z}')
    return np.array(xz_array)/ n_actions

# %% [markdown]
# ## Plot of Empirical Fixed Points vs Path Integral
#
# We note that our Ansatz of the 'most interior' fixed point being the point the system converges to only holds true given sufficiently high exploration (or correspondingly low r).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(15, 6))

xz_array= plot_x_pdf(res.x, 320)

sns.kdeplot(fp, bw_adjust=0.1, clip=(0, 25/320 ))
sns.kdeplot(xz_array, bw_adjust=0.1, clip=(0, 25/320 ))
'''Clipping is neccessary here so there smoothening works out... (ignore evaluating very low probability points for x >>> E(x)) '''

ax.set_xlim((0, 5/320 ));  
ax.set_ylim((0,500))
plt.grid()
plt.legend(['Empirical fixed points', 'Path Integral estimation' ]) 


plt.title("KDE plot of distribution of fixed points")
plt.ylabel("P(x) density")
plt.xlabel("x");
# Out:
# crit_z= 6.722358105727761

# %% [markdown]
# ## Stability Curve

# %% [markdown]
# Below is the stability curve corresponding to the Ansatz above. This had been done through searching tuning the initial conditions for each r and $\Gamma$ by hand.

# %%
import matplotlib.pyplot as plt

r_arr= np.array([0.554,0.537,0.522,0.510,
        0.500, 0.490, 0.482, 0.474, 0.467,
        0.461, 0.454, 0.449, 0.443, 0.438,
        0.433, 0.429, 0.4245, 0.4200, 0.416,
        0.413, 0.409, 0.406, 0.402, 0.399,
        0.396, 0.393, 0.390, 0.387, 0.385,
        0.382, 0.3793, 0.377, 0.3745, 0.3722,
        0.3699, 0.3677, 0.3655, 0.3634, 0.3614,
        0.3594, 0.3574, 0.3555, 0.3537, 0.3518,
        0.3501, 0.3484, 0.3466, 0.3449, 0.3433])
gamma_arr= np.linspace(0.04, 1, 49)


f, ax = plt.subplots(figsize=(15, 6))

plt.plot(1/r_arr, gamma_arr, color='black', marker='*', linestyle='dashed')

plt.plot([1/0.569], [0],'o' )
plt.grid()

ax.set_xlim((0,3)); 
ax.set_ylim((0,1));  

plt.title(" Plot of Stability curve for positive Gamma ")
plt.ylabel("Gamma")
plt.xlabel("r^-1");

# %% [markdown]
# ## Other fixed points
